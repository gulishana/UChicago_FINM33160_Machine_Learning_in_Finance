# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import accuracy_score, confusion_matrix
pd.set_option('use_inf_as_na', True)   # turn the infinity as NA
from collections import Counter

# %% [markdown]
# ## Loading the Data Set (you need to put in the file where you have stored the data)

# %%
raw_data = pd.read_pickle("dataset.pkl")

# %% [markdown]
# ## Restricting to Companies with Market Cap > 1 Billion

# %%
data = raw_data[raw_data['market_cap'] > 1000.0]       # market_cap is measured in millions

# %% [markdown]
# ## The Total Number of Companies w/ Market Cap > 1 Billion that appear during our time horizon

# %%
len(data.index.get_level_values(1).unique())
# Out:
# 4076

# %% [markdown]
# ## Filling in Missing Values

# %%
data.fillna(0.0,inplace=True)
# Out:
# c:\users\gulishana\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %% [markdown]
# ## <font color='red'> Homework Problem 2: </font>
#
# #### <font color='red'> Insert a column in the data set with entries: (1) 2 if the stock return is more then 5% higher than the SPY return; (2) 1 if it is more than 1% but less than 5% higher; (3) 0 if it is between -1% and 1%; (4) -2 if the stock underperforms the SPY by more than -5%; (5) -1 if the performance is between -1% and -5% </font>
#
# #### The function below turns the return differences into labels

# %%
# Here is what you need to change for the homework1 : make new labels     
# then run the whole code file & find out how the strategy works

def f(x):
    if x > 0.05:
        return 2            # labels
    elif x > 0.01:
        return 1
    elif x > -0.01:
        return 0
    elif x > -0.05:
        return -1
    else:
        return -2

# %% [markdown]
# #### Applying the function to the column of relative returns and making a column of labels

# %%
data['rel_performance'] = data['pred_rel_return'].apply(f)
# Out:
# c:\users\gulishana\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### This is the column of labels

# %%
data['rel_performance']
# Out:
# date        ticker
# 2000-02-09  CSCO     -1
#             ROP       2
# 2000-02-10  CMOS      2
# 2000-02-11  DELL      2
# 2000-02-15  VAL       1
# 2000-02-16  AMAT      2
#             ANF      -2
#             DE        2
#             EV        2
#             NAV      -1
#             NTAP     -2
#             NVDA      2
#             WMT       2
#             ZLC       2
# 2000-02-17  ADI       2
#             ADIC     -2
#             CPB      -1
#             TWE       2
# 2000-02-18  A        -1
#             ADCT      2
#             AGIL     -2
#             BRCD      1
#             CIEN      2
#             HRL      -2
#             JWN       2
#             NOVL     -2
#             SCMR     -2
#             SNPS      2
# 2000-02-23  BEAS     -2
#             DG        2
#                      ..
# 2018-12-18  RHT       0
# 2018-12-19  ABM       0
#             AIR       0
#             DRI       0
#             FDS       0
#             FDX       0
#             JBL       0
#             MU        0
#             NAV       0
#             SCS       0
#             WOR       0
# 2018-12-20  GIS       0
#             MLHR      0
#             PAYX      0
#             RAD       0
# 2018-12-21  ACN       0
#             APOG      0
#             ATU       0
#             BB        0
#             CAG       0
#             CCL       0
#             CTAS      0
#             CVGW      0
#             KANG      0
#             NEOG      0
#             NKE       0
#             SAFM      0
#             SCHL      0
#             WBA       0
# 2018-12-24  KMX       0
# Name: rel_performance, Length: 111468, dtype: int64

# %% [markdown]
# ### Make date the index, remember that the date is the first business day after Earnings Release

# %%
data.reset_index(inplace=True)    # make original index as columns
data.set_index('date', inplace=True)    # set "date" as index
# inplace=True: don't use too much memory by not making copies

# %% [markdown]
# ### This what the data set looks like now

# %%
data
# Out:
#            ticker       actq        apq        atq       ceqq      cheq  \
# date
# 2000-02-09   CSCO   7722.000    482.000  21391.000  16523.000  3968.000
# 2000-02-09    ROP    172.725     19.662    474.649    239.432     3.198
# 2000-02-10   CMOS    240.767     27.044    376.536    209.411    68.625
# 2000-02-11   DELL   7681.000   3538.000  11471.000   5308.000  4132.000
# 2000-02-15    VAL    507.082    139.497   1094.080    402.382    27.605
# 2000-02-16   AMAT   5462.528   1343.693   7057.999   4756.546  3004.177
# 2000-02-16    ANF    300.217     18.714    458.166    311.094   193.509
# 2000-02-16     DE      0.000   2327.700  18144.400   4094.800   297.500
# 2000-02-16     EV    112.154     14.347    380.413    216.571   100.008
# 2000-02-16    NAV   2980.000   1051.000   6444.000   1313.000   606.000
# 2000-02-16   NTAP    447.428     21.991    493.916    416.113   290.052
# 2000-02-16   NVDA    173.175     64.910    202.250    124.563    61.560
# 2000-02-16    WMT  24356.000  13105.000  70349.000  25834.000  1856.000
# 2000-02-16    ZLC   1345.076    345.758   1719.492    757.417    65.670
# 2000-02-17    ADI   1558.961    125.027   2489.333   1746.345   895.222
# 2000-02-17   ADIC    253.665     29.487    473.185    353.893   161.481
# 2000-02-17    CPB   1439.000    446.000   5564.000    265.000    92.000
# 2000-02-17    TWE      0.000   8196.049  11841.949   2012.234   905.878
# 2000-02-18      A   4982.000    635.000   7107.000   4486.000  1410.000
# 2000-02-18   ADCT   1137.412    103.291   1814.519   1396.005   364.315
# 2000-02-18   AGIL    317.692      1.839    439.884    422.857   310.469
# 2000-02-18   BRCD    124.951     14.791    135.112     93.180    96.429
# 2000-02-18   CIEN    558.478     38.431    707.158    562.725   258.537
# 2000-02-18    HRL    764.826    164.688   1663.679    846.787   217.930
# 2000-02-18    JWN   1564.648    390.688   3062.081   1185.614    52.569
# 2000-02-18   NOVL   1265.819     57.523   2019.009   1601.012   947.515
# 2000-02-18   SCMR    329.541     28.218    344.678    307.180   288.576
# 2000-02-18   SNPS    874.411     80.870   1177.854    877.004   651.067
# 2000-02-23   BEAS    971.377     14.848   1258.841    444.819   803.060
# 2000-02-23     DG   1095.535    334.554   1450.941    925.921    58.789
# ...           ...        ...        ...        ...        ...       ...
# 2018-12-18    RHT   2970.491    432.662   5103.014   1423.631  1927.157
# 2018-12-19    ABM   1171.000    221.900   3627.500   1454.600    39.100
# 2018-12-19    AIR   1040.700    205.200   1604.200    935.600    40.700
# 2018-12-19    DRI    561.200    301.300   5549.200   2250.300   139.700
# 2018-12-19    FDS    391.183     61.271   1365.927    541.209   197.848
# 2018-12-19    FDX  13438.000   3400.000  53289.000  19294.000  2123.000
# 2018-12-19    JBL   8220.739   5458.398  12778.337   1891.916   804.409
# 2018-12-19     MU  15039.000   1683.000  44595.000  33869.000  5563.000
# 2018-12-19    NAV   5136.000   1606.000   7230.000  -3933.000  1483.000
# 2018-12-19    SCS    796.900    277.700   1980.600    854.500    51.000
# 2018-12-19    WOR   1187.616    406.444   2562.437    868.672    93.027
# 2018-12-20    GIS   4233.800   2823.900  30384.000   6651.800   532.700
# 2018-12-20   MLHR    601.000    184.600   1509.700    685.200   121.800
# 2018-12-20   PAYX   5290.000     70.600   7002.400   2424.500   759.000
# 2018-12-20    RAD   4330.478   1707.242   8082.958   1453.414   410.043
# 2018-12-21    ACN  13540.408   1355.538  26706.412  12678.799  4366.906
# 2018-12-21   APOG    372.775     79.072   1080.980    530.874    15.485
# 2018-12-21    ATU    707.335    124.067   1450.033    537.565   203.443
# 2018-12-21     BB   2544.000     32.000   3676.000   2519.000  2318.000
# 2018-12-21    CAG   3275.400   1246.100  23006.800   7224.100   442.300
# 2018-12-21    CCL   2225.000    730.000  42401.000  24443.000   981.000
# 2018-12-21   CTAS   2215.870    211.900   7405.083   3027.244    88.479
# 2018-12-21   CVGW    128.510     27.736    367.736    263.211     1.520
# 2018-12-21   KANG    353.163     59.219    893.553    362.101    38.276
# 2018-12-21   NEOG    414.294     20.555    660.492    602.074   240.970
# 2018-12-21    NKE  15566.000   2574.000  22677.000   8729.000  4041.000
# 2018-12-21   SAFM    566.489    128.936   1659.440   1387.893   121.193
# 2018-12-21   SCHL   1172.300    250.300   2081.900   1284.600   358.100
# 2018-12-21    WBA  20083.000  14660.000  69941.000  25609.000  1183.000
# 2018-12-24    KMX   3057.419    558.324  18396.812   3435.113   461.662
#
#                 cogsq     csh12q    cshfdq     cshiq  ...  sector_code_817.0  \
# date                                                  ...
# 2000-02-09   1422.000  3374.1250  3648.000  3445.000  ...                  0
# 2000-02-09     47.634    30.2688    31.217     0.000  ...                  0
# 2000-02-10     43.023    21.4360    23.753     0.000  ...                  0
# 2000-02-11   5452.000  2536.0000  2731.000  2575.000  ...                  0
# 2000-02-15    221.366    43.1858    43.687    53.321  ...                  0
# 2000-02-16    777.332   389.5113   409.817   386.487  ...                  0
# 2000-02-16    170.010   102.8710   105.703   104.104  ...                  0
# 2000-02-16   1714.500   233.4500   236.300   265.879  ...                  0
# 2000-02-16     56.495    35.8978    36.927    35.526  ...                  0
# 2000-02-16   1747.000    64.3250    63.700    75.300  ...                  0
# 2000-02-16     57.528   146.4985   175.168   152.285  ...                  0
# 2000-02-16     79.809    29.8720    37.551    31.100  ...                  0
# 2000-02-16  39931.000  4451.0000  4479.000  4457.000  ...                  0
# 2000-02-16    375.411    35.7908    35.983     0.000  ...                  0
# 2000-02-17    189.711   172.0170   187.229   179.362  ...                  0
# 2000-02-17     40.961    21.8385    26.861    25.702  ...                  0
# 2000-02-17    843.000   431.7500   431.000   542.000  ...                  0
# 2000-02-17    263.748   376.4190   376.419   376.419  ...                  0
# 2000-02-18      0.000   394.7500   440.000   452.000  ...                  0
# 2000-02-18    291.300   162.6315   182.525   151.686  ...                  0
# 2000-02-18      1.522    10.7048    21.079    23.083  ...                  0
# 2000-02-18     20.084    38.4355    58.884    54.146  ...                  0
# 2000-02-18     74.012   133.0053   147.903   139.810  ...                  0
# 2000-02-18    624.727    72.5255    71.895    70.754  ...                  0
# 2000-02-18    959.833   137.8150   133.782   132.280  ...                  0
# 2000-02-18     60.222   331.8265   342.105   327.700  ...                  0
# 2000-02-18     14.120    21.5350    65.878    78.698  ...                  0
# 2000-02-18     18.104    70.7850    74.281     0.000  ...                  0
# 2000-02-23     51.757   155.4090   161.240   180.932  ...                  0
# 2000-02-23    816.152   244.0190   269.562   264.692  ...                  0
# ...               ...        ...       ...       ...  ...                ...
# 2018-12-18    101.158   176.8300   186.062   242.610  ...                  0
# 2018-12-19   1455.700    66.1000    66.600    66.004  ...                  0
# 2018-12-19    404.600    34.3000    35.000    45.301  ...                  0
# 2018-12-19   1586.700   123.7500   125.800   124.773  ...                  0
# 2018-12-19    152.535    38.4883    38.809    39.447  ...                  0
# 2018-12-19  13245.000   264.5000   266.000   318.000  ...                  0
# 2018-12-19   5805.435   168.4185   163.670   258.817  ...                  0
# 2018-12-19   1963.000  1151.7500  1174.000  1172.000  ...                  0
# 2018-12-19   2651.000    98.9000    99.700   103.100  ...                  0
# 2018-12-19    590.800   117.0750   117.000   116.800  ...                  0
# 2018-12-19    813.767    59.0475    59.338    56.957  ...                  0
# 2018-12-20   2745.200   589.2500   604.500   754.600  ...                  0
# 2018-12-20    398.500    59.4108    59.442    58.902  ...                  0
# 2018-12-20    228.100   359.1000   361.500   359.091  ...                  0
# 2018-12-20   4181.287  1055.7388  1058.395  1066.902  ...                  0
# 2018-12-21   7165.315   634.1310   652.151   665.541  ...                  0
# 2018-12-21    261.707    28.0970    28.156    27.656  ...                  0
# 2018-12-21    182.911    60.7313    61.031    81.503  ...                  0
# 2018-12-21     52.000   537.8368   600.906   547.084  ...                  0
# 2018-12-21   1599.900   401.8500   421.800   584.219  ...                  0
# 2018-12-21   2741.000   709.0000   699.000   873.000  ...                  0
# 2018-12-21    854.734   106.6853   109.874   184.153  ...                  0
# 2018-12-21    254.493    17.4770    17.581    17.567  ...                  0
# 2018-12-21     85.636    69.1580    72.099     0.000  ...                  0
# 2018-12-21     52.739    51.6338    52.591    52.082  ...                  0
# 2018-12-21   5098.000  1601.1500  1620.700  1577.000  ...                  0
# 2018-12-21    758.313    22.4290    22.191    22.100  ...                  0
# 2018-12-21    262.400    35.0420    35.863     0.000  ...                  0
# 2018-12-21  25651.000   976.4750   951.400  1172.514  ...                  0
# 2018-12-24   3819.336   177.2235   175.321   171.785  ...                  0
#
#             sector_code_822.0  sector_code_823.0  sector_code_825.0  \
# date
# 2000-02-09                  0                  0                  0
# 2000-02-09                  0                  0                  0
# 2000-02-10                  0                  0                  0
# 2000-02-11                  0                  0                  0
# 2000-02-15                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  1                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-17                  0                  0                  0
# 2000-02-17                  0                  0                  0
# 2000-02-17                  0                  0                  0
# 2000-02-17                  1                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-23                  0                  0                  0
# 2000-02-23                  0                  0                  0
# ...                       ...                ...                ...
# 2018-12-18                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-24                  0                  0                  0
#
#             sector_code_830.0  sector_code_835.0  sector_code_840.0  \
# date
# 2000-02-09                  0                  0                  0
# 2000-02-09                  0                  0                  0
# 2000-02-10                  0                  0                  0
# 2000-02-11                  0                  0                  0
# 2000-02-15                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-16                  0                  0                  0
# 2000-02-17                  0                  0                  0
# 2000-02-17                  0                  0                  0
# 2000-02-17                  0                  0                  0
# 2000-02-17                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-18                  0                  0                  0
# 2000-02-23                  0                  0                  0
# 2000-02-23                  0                  0                  0
# ...                       ...                ...                ...
# 2018-12-18                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-19                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-20                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-24                  0                  0                  0
#
#             sector_code_845.0  sector_code_850.0  rel_performance
# date
# 2000-02-09                  0                  0               -1
# 2000-02-09                  0                  0                2
# 2000-02-10                  0                  0                2
# 2000-02-11                  0                  0                2
# 2000-02-15                  0                  0                1
# 2000-02-16                  0                  0                2
# 2000-02-16                  0                  0               -2
# 2000-02-16                  0                  0                2
# 2000-02-16                  0                  0                2
# 2000-02-16                  0                  0               -1
# 2000-02-16                  0                  0               -2
# 2000-02-16                  0                  0                2
# 2000-02-16                  0                  0                2
# 2000-02-16                  0                  0                2
# 2000-02-17                  0                  0                2
# 2000-02-17                  0                  0               -2
# 2000-02-17                  0                  0               -1
# 2000-02-17                  0                  0                2
# 2000-02-18                  0                  0               -1
# 2000-02-18                  0                  0                2
# 2000-02-18                  0                  0               -2
# 2000-02-18                  0                  0                1
# 2000-02-18                  0                  0                2
# 2000-02-18                  0                  0               -2
# 2000-02-18                  0                  0                2
# 2000-02-18                  0                  0               -2
# 2000-02-18                  0                  0               -2
# 2000-02-18                  0                  0                2
# 2000-02-23                  0                  0               -2
# 2000-02-23                  0                  0                2
# ...                       ...                ...              ...
# 2018-12-18                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-19                  0                  0                0
# 2018-12-20                  0                  0                0
# 2018-12-20                  0                  0                0
# 2018-12-20                  0                  0                0
# 2018-12-20                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-21                  0                  0                0
# 2018-12-24                  0                  0                0
#
# [111468 rows x 733 columns]

# %% [markdown]
# #### We use a training period of 3 years = 12 quarters, and choose two random 3 year time spans as training and test sets

# %%
df_1 = data.loc['2008-01-01':'2011-01-01']
df_2 = data.loc['2015-04-01':'2018-04-01']

# %% [markdown]
# #### The validation set and test set are the quarters starting 1 quarter after the end of the training periods

# %%
df_valid = data.loc['2012-04-01':'2012-07-01']   # 应该改成 2011
df_test = data.loc['2018-07-01':'2018-10-01']

# %% [markdown]
# #### Next we delete the columns that are not needed for training

# %%
train_1 = df_1.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)
train_2 = df_2.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)

valid = df_valid.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)
test = df_test.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)

# %% [markdown]
# #### We take out the actual  earnings period stock returns in the training and test sets

# %%
train_1_stock_returns = df_1['next_period_return']
valid_stock_returns = df_valid['next_period_return']
train_2_stock_returns = df_2['next_period_return']
test_stock_returns = df_test['next_period_return']

# %% [markdown]
# #### and the labels for the training and validation and test data. We turn them into arrays by applying the .values method

# %%
y_1 = df_1['rel_performance']
y_2 = df_2['rel_performance']
y_valid = df_valid['rel_performance']
y_test = df_test['rel_performance']

# %%
y_1 = y_1.values
y_2 = y_2.values
y_valid = y_valid.values
y_test = y_test.values

# %% [markdown]
# ## Number of Features

# %%
len(train_1.columns)
# Out:
# 725

# %% [markdown]
# ## Importing the Tree Classifier and some metrics from sklearn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %% [markdown]
# ## Instantiating the classifiers with hyper-parameters

# %%
t_clf = DecisionTreeClassifier(min_samples_leaf =600,max_depth=8,random_state=123)
# min_samples_leaf: minimum samples in each leaf we allow for
# if not defined, tree will run all the possible ones to the best fit for the training data (-> overfitting)

# max_depth also helps to restrict the overfitting

# if only use random_state, it will overfit, gives score=1 in the training data

# %% [markdown]
# ## Now we can fit the tree with the training data

# %%
t_clf.fit(train_1,y_1)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=600, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=123,
#             splitter='best')

# %% [markdown]
# ### and see how well it fits the training data

# %%
t_clf.score(train_1,y_1)    # accurary=1 is the perfect fit   (opposite to error rate)
# Out:
# 0.4292996877588734

# %% [markdown]
# ### and predicts the validation data (not very well)

# %%
t_clf.score(valid,y_valid)
# Out:
# 0.25668116842759475

# %% [markdown]
# ### The predicted labels on the validation set and their counts

# %%
pred_valid = t_clf.predict(valid)

# %%
Counter(pred_valid)
# Out:
# Counter({2: 1451, -2: 158})

# %% [markdown]
# ### Visualizing the tree

# %%
import graphviz
from sklearn import tree

# %%
# tell Python where the Graphviz bin folder is (the PATH)
import os
os.environ["PATH"] += os.pathsep + 'D:/Program Files/Python related/graphviz-2.38/bin/'

# %%
dot_data = tree.export_graphviz(t_clf,out_file=None)
graph = graphviz.Source(dot_data)
graph.render('Tree_2')
graph

# %% [markdown]
# ## Now we are going to cut the features by looking at their importance in the tree. The visualization of the tree shows that only a few of the features are actually used

# %%
def tree_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'feat_imp':m.feature_importances_}
                       ).sort_values('feat_imp', ascending=False)

def plot_fi(fi): return fi.plot('cols', 'feat_imp', 'barh', figsize=(12,7), legend=False)

# %%
fi = tree_feat_importance(t_clf,train_1)

# %%
fi
# Out:
#                   cols  feat_imp
# 55                teqq  0.169562
# 180             fqtr_2  0.120818
# 86              dvpspq  0.100848
# 71                dpcy  0.071091
# 175          sale_nwcq  0.069729
# 92          market_cap  0.053013
# 44                 piq  0.049520
# 178           accrualq  0.048399
# 147       debt_ebitdaq  0.046910
# 113              ptpmq  0.043309
# 62                xrdq  0.036319
# 142       int_totdebtq  0.033483
# 69              dltisy  0.032823
# 4                 cheq  0.026486
# 160       debt_assetsq  0.022953
# 100            pe_incq  0.022163
# 152           ocf_lctq  0.020540
# 111             opmadq  0.020180
# 73              ibcomy  0.011854
# 492           sic_5735  0.000000
# 490           sic_5731  0.000000
# 501           sic_5961  0.000000
# 491           sic_5734  0.000000
# 494           sic_5812  0.000000
# 493           sic_5810  0.000000
# 497           sic_5940  0.000000
# 495           sic_5900  0.000000
# 500           sic_5960  0.000000
# 499           sic_5945  0.000000
# 498           sic_5944  0.000000
# ..                 ...       ...
# 275           sic_2851  0.000000
# 276           sic_2860  0.000000
# 277           sic_2870  0.000000
# 278           sic_2890  0.000000
# 279           sic_2891  0.000000
# 280           sic_2911  0.000000
# 281           sic_2950  0.000000
# 263           sic_2790  0.000000
# 261           sic_2761  0.000000
# 241           sic_2452  0.000000
# 250           sic_2621  0.000000
# 242           sic_2510  0.000000
# 243           sic_2511  0.000000
# 244           sic_2520  0.000000
# 245           sic_2522  0.000000
# 246           sic_2531  0.000000
# 247           sic_2540  0.000000
# 248           sic_2590  0.000000
# 249           sic_2611  0.000000
# 251           sic_2631  0.000000
# 260           sic_2750  0.000000
# 252           sic_2650  0.000000
# 253           sic_2670  0.000000
# 254           sic_2673  0.000000
# 255           sic_2711  0.000000
# 256           sic_2721  0.000000
# 257           sic_2731  0.000000
# 258           sic_2732  0.000000
# 259           sic_2741  0.000000
# 724  sector_code_850.0  0.000000
#
# [725 rows x 2 columns]

# %% [markdown]
# ## We are only going to use the features that have positive feature importance i.e. occur in the tree

# %%
features = fi[(fi['feat_imp'] > 0.00)]

# %% [markdown]
# ### Feature importance spectrum

# %%
plot_fi(features);

# %% [markdown]
# #### We are left with a much smaller set of features

# %%
len(features['cols'].values)
# Out:
# 19

# %% [markdown]
# ### We cut down the training and validation data sets to only include the relevant features and retrain the tree on the reduced data set

# %%
train_1 = train_1[features['cols'].values]

# %%
t_clf.fit(train_1,y_1)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=600, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=123,
#             splitter='best')

# %%
t_clf.score(train_1,y_1)
# Out:
# 0.4292996877588734

# %%
valid = valid[features['cols'].values]

# %%
t_clf.score(valid,y_valid)
# Out:
# 0.25668116842759475

# %%
pred_valid = t_clf.predict(valid)

# %%
confusion_matrix(y_valid,pred_valid)
# Out:
# array([[ 30,   0,   0,   0, 547],
#        [ 24,   0,   0,   0, 221],
#        [ 14,   0,   0,   0, 106],
#        [ 37,   0,   0,   0, 194],
#        [ 53,   0,   0,   0, 383]], dtype=int64)

# %% [markdown]
# ## We are really only interested in how much return the strategy generates over the validation period

# %%
(pred_valid * df_valid['next_period_return']).sum()
# Out:
# -45.16406600000002

# %% [markdown]
# ### We define the Profit Importance of a feature by how much removing the feature affects the profit (positivly or negatively). By scrambling the feature column we get a column which should have to effect on the profit and we compute the profit with the scrambled column. Because the scrambling is random we use 100 random permutations and take the average.

# %%
def profit_importance(t,df,rets):
#     np.random.seed(123)
    profit = []
    for col in df.columns:
            X = df.copy()   # make a new copy of the dataframe
            X[col] = np.random.permutation(df[col].values)
            prediction = t.predict(X)
            profit.append((prediction * rets).sum())
    return profit

# %%
def tree_profit_importance(m, df,rets):
    return pd.DataFrame({'cols':df.columns, 'pi_imp':profit_importance(m,df,rets)}
                       ).sort_values('pi_imp', ascending=True)

# %%
pi = tree_profit_importance(t_clf,valid,df_valid['next_period_return'])
pi
# Out:
#             cols     pi_imp
# 1         fqtr_2 -47.038030
# 4      sale_nwcq -45.429518
# 18        ibcomy -45.164066
# 16      ocf_lctq -45.164066
# 3           dpcy -45.164066
# 5     market_cap -45.164066
# 6            piq -45.164066
# 7       accrualq -45.164066
# 8   debt_ebitdaq -45.164066
# 17        opmadq -45.164066
# 10          xrdq -45.164066
# 12        dltisy -45.164066
# 13          cheq -45.164066
# 15       pe_incq -45.164066
# 11  int_totdebtq -44.739686
# 9          ptpmq -44.680346
# 0           teqq -41.553690
# 2         dvpspq -36.588510
# 14  debt_assetsq -29.122582

# %% [markdown]
# ## We now remove the features one at a time from the bottom of the profit importance list and recompute the profit. At each step we retrain the tree and remove features that may become irrelevant. We then compute a new profit importance list and remove the last item etc. The features are very interdependent so removing a feature can greatly affect the profit importances of the remaining features

# %%
profits = []
feat=[]
train = train_1.copy()
validation = valid.copy()
while len(train.columns)>2:
    t_clf.fit(train,y_1)
    pi = tree_profit_importance(t_clf,validation,valid_stock_returns)

    col_to_drop = pi[pi['pi_imp'] == pi['pi_imp'].max()]['cols'].iloc[0]
    # col_to_drop = pi.iloc[-1]["cols"]        # solving the problem in the slide
    
    train.drop(col_to_drop,axis=1,inplace=True)
    validation.drop(col_to_drop,axis=1,inplace=True)
    t_clf.fit(train,y_1)
    fi = tree_feat_importance(t_clf,train)
    features = fi[(fi['feat_imp'] > 0.00)]
    train = train[features['cols'].values]     
    validation = validation[features['cols'].values]
    t_clf.fit(train,y_1)
    pred_valid = t_clf.predict(validation)
    profits.append((pred_valid * df_valid['next_period_return']).sum())
    feat.append(features['cols'].values)

# %% [markdown]
# ### We plot the profits for the steps and find the step where the profit is maximal and take the corresponding set of features as the optimal feature set

# %%
plt.plot(profits);

# %%
n = np.argmax(profits)
max_profits = profits[n]
optim_feats = feat[n]

# %%
print(max_profits)
print(optim_feats)
# Out:
# -30.131370000000032
# ['teqq' 'fqtr_2' 'piq' 'accrualq' 'debt_ebitdaq' 'opmadq' 'ocf_lctq']

# %% [markdown]
# ### We restrict the traing set to the optimal features and retrain the tree on the reduces data set

# %%
train_1_optim = train_1[optim_feats]
valid_optim = valid[optim_feats]

t_clf.fit(train_1_optim,y_1)
pred_valid_tree = t_clf.predict(valid_optim)
(pred_valid_tree * df_valid['next_period_return']).sum()
# Out:
# -30.131370000000032

# %% [markdown]
# ## How well does it do on the test set?

# %%
train_2_tree = train_2[optim_feats]
test_tree = test[optim_feats]
t_clf.fit(train_2_tree,y_2)
pred_test_tree = t_clf.predict(test_tree)
(pred_test_tree * df_test['next_period_return']).sum()
# Out:
# -41.13116400000003

# %% [markdown]
# ## If we were 100% correct on the validation set we would get this profit

# %%
(y_valid * df_valid['pred_rel_return']).sum()
# Out:
# 321.15558499999986

# %% [markdown]
# ## A totally random strategy where we randomly decide whether to buy or sell

# %%
m = len(df_test['next_period_return'])

# %%
random_predictions = []
for _ in range(1000):
    pred_random = np.random.choice([-1,0,1],m)
    random_predictions.append((pred_random * df_test['next_period_return']).sum())

# %%
plt.hist(random_predictions,bins=30,density=True);

# %%
np.mean(random_predictions)
# Out:
# -0.117988758999999

# %% [markdown]
# ## Now we run this strategy over the whole period and see how it performs

# %%
start_dates = [pd.to_datetime('2000-01-01') + pd.DateOffset(months = 3 * i) for i in range(62)]
end_dates = [d + pd.DateOffset(months = 36) for d in start_dates]

# %%
training_frames = [data.loc[d:d+pd.DateOffset(months=36)] for d in start_dates]
test_frames = [data.loc[d+pd.DateOffset(months=3):d+pd.DateOffset(months=6)] for d in end_dates]

# %%
training_data = [d.reset_index().drop
                                 (['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1) for d in training_frames]

# %%
test_data = [d.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1) for d in test_frames]

# %%
training_labels = [d['rel_performance'].values for d in training_frames]

# %%
opt_training_data = [t[optim_feats] for t in training_data]
opt_test_data = [v[optim_feats] for v in test_data]

# %%
P_L = []
x = [1]
ret = []

for i in range(len(training_labels)-1):
        t_clf.fit(opt_training_data[i],training_labels[i])
        pred_i = t_clf.predict(opt_test_data[i])
        profit_i = (pred_i * test_frames[i]['next_period_return']).sum()
        P_L.append(profit_i)
        num_positions = len(pred_i)
        ret.append((1.0/num_positions) * profit_i)
        x.append(x[i] + (x[i]/num_positions) * profit_i)

# %%
plt.plot(x);

# %% [markdown]
# ## Compared to a buy-and-hold of SPY

# %%
SPY = pd.read_pickle("SPY_cum_ret.pkl")
SPY = SPY.loc['2003-04-01':'2018-09-30']
SPY = SPY.resample('Q').ffill()
SPY['spy_cum_ret'] = (SPY['spy_cum_ret'] - SPY['spy_cum_ret'][0] + 1)
SPY['strategy'] = x

# %%
SPY.plot();

# %%
strategy_mean_ret = (SPY['strategy'] - 1).diff().mean()
strategy_std = (SPY['strategy'] - 1).diff().std()
print('Strategy Sharpe Ratio: ',strategy_mean_ret/strategy_std)
# Out:
# Strategy Sharpe Ratio:  0.2500125073645216

# %%
spy_mean_ret = (SPY['spy_cum_ret'] - 1).diff().mean()
spy_std = (SPY['spy_cum_ret'] - 1).diff().std()
print('SPY Sharpe Ratio: ',spy_mean_ret/spy_std)
# Out:
# SPY Sharpe Ratio:  0.4100834330712901

# %% [markdown]
# ### Total Returns

# %%
x[-1]
# Out:
# 6.73328411659999

# %%
SPY['spy_cum_ret'][-1]
# Out:
# 2.64168

# %% [markdown]
# ### Computing the (quarterly) $\alpha$ of the strategy

# %%
strategy_ret = (SPY['strategy'] - 1).diff().values[1:]
spy_ret = (SPY['spy_cum_ret'] - 1).diff().values[1:]

# %%
beta = (np.cov(spy_ret,strategy_ret)/np.var(spy_ret))[1,0]
beta
# Out:
# 2.6373302985174245

# %%
residual_ret = strategy_ret - beta * spy_ret
IR = np.mean(residual_ret)/np.std(residual_ret)
IR
# Out:
# 0.06921865614224026

# %%
alpha = np.mean(residual_ret)
alpha
# Out:
# 0.02301035593655582
